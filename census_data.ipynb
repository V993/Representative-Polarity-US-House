# %%
import requests
import pandas as pd

# %%
# Key for US Census API
api_key = "b2f0093083dbdc9c8cd365c93d0687c5616536fa"

# %%
# IRS SAIPE (Small Area Income and Poverty Estimates) from US Census data:
# https://www.census.gov/data/datasets/time-series/demo/saipe/model-tables.html

saipe_df = pd.read_excel("irs.xls",skiprows=2)
saipe_df.head()
# Out:
#    State FIPS code     Name  Year  Total exemptions  Poor exemptions  \
# 0                1  Alabama  1989           3367441           634363
# 1                1  Alabama  1990           3427361           676616
# 2                1  Alabama  1991           3471467           720465
# 3                1  Alabama  1992           3494455           711496
# 4                1  Alabama  1993           3518338           728239
#
#    Age 65 and over exemptions  Age 65 and over poor exemptions  \
# 0                      213228                            30357
# 1                      223095                            34114
# 2                      229666                            36826
# 3                      227683                            35158
# 4                      227765                            35485
#
#    Child exemptions  Poor child exemptions  Total exemptions under age 65  \
# 0           1145821                 260472                        3154213
# ...

# %%
saipe_df.groupby(["State FIPS code", "Name"]).mean()
# Out:
#                                         Year  Total exemptions  \
# State FIPS code Name
# 1               Alabama               2004.5      3.709298e+06
# 2               Alaska                2004.5      5.732106e+05
# 4               Arizona               2004.5      4.529483e+06
# 5               Arkansas              2004.5      2.227062e+06
# 6               California            2004.5      2.892251e+07
# 8               Colorado              2004.5      3.974140e+06
# 9               Connecticut           2004.5      2.967646e+06
# 10              Delaware              2004.5      7.138026e+05
# 11              District of Columbia  2004.5      4.513057e+05
# 12              Florida               2004.5      1.432119e+07
# 13              Georgia               2004.5      7.261596e+06
# 15              Hawaii                2004.5      1.099681e+06
# 16              Idaho                 2004.5      1.236797e+06
# ...

# %%
# 117th Congress (2021 - 2022)
